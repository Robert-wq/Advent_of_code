# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('input.txt', names=['number'], dtype=str)
df
# Out:
#            number
# 0    101010011010
# 1    101111111001
# 2    100100100000
# 3    000001010010
# 4    100100110011
# ..            ...
# 995  001101100100
# 996  001000010010
# 997  010000000011
# 998  000110000010
# 999  000001101000
#
# [1000 rows x 1 columns]

# %%
num_arr = df['number'].to_numpy()
num_arr
# Out:
# array(['101010011010', '101111111001', '100100100000', '000001010010',
#        '100100110011', '000101100110', '101011001001', '100001111101',
#        '011001001101', '010000110101', '001111101111', '010110111000',
#        '000010001100', '011101111011', '111111100111', '010011101011',
#        '010110001000', '001111001010', '000110101011', '011001110101',
#        '001110001111', '101100001101', '010111110010', '110000000000',
#        '001101110110', '111111101011', '110011110110', '100011110110',
#        '010111000001', '111010100110', '100001011101', '110010110110',
#        '111101010111', '000011110001', '110101010000', '111101101000',
#        '000001111110', '100101000011', '100101001010', '111001001011',
#        '010110011110', '111111010111', '111000000111', '101000101100',
#        '000000101100', '111010001010', '000000001110', '011001111101',
#        '000000111010', '010001000001', '110101100000', '101010100001',
# ...

# %% [markdown]
# //TODO
#
# - 12 times
# - Loop through each binary value
# - count how many ones and zeros there are
# - the most common is added to the gamma total
# - the least common is added to the epsilon total.
# - multiply the two values

# %%
gamma = 0
epsilon = 0

for i in range(len(num_arr[0])):
    one_count = 0
    zero_count = 0
    for j in range(len(num_arr)):
        if num_arr[j][i] == '1':
            one_count += 1
        else:
            zero_count += 1
            
    if(one_count >= zero_count):
        #gets the number from 2 ** 11 to 2 ** 0, had to add the extra '-1' to account for 0 index
        gamma += (2 ** ((len(num_arr[0]) - 1) - i)) 
    else:
        epsilon += (2 ** ((len(num_arr[0]) - 1) - i))
    
    print(str(len(num_arr[0]) - i) + ' = ' + str(one_count))
    print('gamma = ' + str(gamma))
    print('epsilon = ' + str(epsilon))
# Out:
# 12 = 512
# gamma = 2048
# epsilon = 0
# 11 = 501
# gamma = 3072
# epsilon = 0
# 10 = 498
# gamma = 3072
# epsilon = 512
# 9 = 517
# gamma = 3328
# epsilon = 512
# 8 = 479
# gamma = 3328
# epsilon = 640
# 7 = 484
# gamma = 3328
# epsilon = 704
# 6 = 484
# gamma = 3328
# epsilon = 736
# 5 = 505
# gamma = 3344
# epsilon = 736
# 4 = 486
# gamma = 3344
# epsilon = 744
# 3 = 501
# gamma = 3348
# epsilon = 744
# 2 = 491
# gamma = 3348
# epsilon = 746
# 1 = 512
# gamma = 3349
# epsilon = 746

# %%
result = gamma * epsilon
result
# Out:
# 2498354
